# %% [markdown]
# # Sandpit Notebook
#
# For exploring data and testing approaches

# %% [markdown]
# ## Libraries

# %%
import pandas  as pd
import geopandas as gpd
import requests
import os
from datetime import datetime
import numpy as np
from string import digits
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\2031144169.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas  as pd

# %% [markdown]
# ## Explore ICB Data

# %%
FOLDERPATH = "../data/ICB Level CSVs/"
data_icb_all = pd.DataFrame()
for file in os.listdir(FOLDERPATH):
    data = pd.read_csv(FOLDERPATH+file)
    date = file.split(".")[0]
    data["date_str"] = date
    data["date"] = datetime.strptime(date, '%B-%y')
    data_icb_all = pd.concat([data_icb_all, data])

# %%
icb_tier3_list = ["NHS Cheshire And Merseyside Integrated Care Board",
                    "NHS Cornwall And The Isles Of Scilly Integrated Care Board",
                    "NHS Devon Integrated Care Board",
                    "NHS Greater Manchester Integrated Care Board",
                    "NHS Kent And Medway Integrated Care Board",
                    "NHS Norfolk And Waveney Integrated Care Board",
                    "NHS North East London Integrated Care Board"]

tier3 =  ["Yes"] * len(icb_tier3_list)

data_icb_all = pd.merge(data_icb_all, pd.Series(tier3, icb_tier3_list, name='tier3'), left_on='System', right_index=True, how='left')
data_icb_all.tier3 = data_icb_all['tier3'].fillna("No")

# %%
print(data_icb_all.shape)
print(data_icb_all.columns)
data_icb_all.head(3)
# Out:
# (924, 29)
# Index(['Code', 'System', 'Attendances (Type 1)', 'Attendances (Type 2)',
#        'Attendances (Type 3)', 'Attendances (Total) ',
#        'Attendances in 4 hours or less (Type 1)',
#        'Attendances in 4 hours or less (Type 2)',
#        'Attendances under 4 hours (Type 3)',
#        'Attendances under 4 hours (Total)',
#        'Attendances over 4 hours (Type 1)',
#        'Attendances over 4 hours (Type 2)',
#        'Attendances over 4 hours (Type 3)', 'Attendances over 4 hours (Total)',
#        'Percentage in 4 hours or less (Total)',
#        'Percentage in 4 hours or less (Type 1)',
#        'Percentage in 4 hours or less (Type 2)',
#        'Percentage in 4 hours or less (Type 3)',
#        'Emergency Admissions via Type 1 A&E',
#        'Emergency Admissions via Type 2 A&E',
#        'Emergency Admissions via Type 3 and 4 A&E',
#        'Total Emergency Admissions via A&E',
#        'Other Emergency admissions (i.e not via A&E)',
#        'Total Emergency Admissions',
#        'Number of patients spending >4 hours from decision to admit to admission',
#        'Number of patients spending >12 hours from decision to admit to admission',
#        'date_str', 'date', 'tier3'],
#       dtype='object')
#   Code                                             System  \
# 0  QOX  NHS Bath And North East Somerset, Swindon And ...
# 1  QHG  NHS Bedfordshire, Luton And Milton Keynes Inte...
# 2  QHL  NHS Birmingham And Solihull Integrated Care Board
#
#   Attendances (Type 1) Attendances (Type 2) Attendances (Type 3)  \
# 0               16,474                  249                8,983
# 1               21,440                    0               11,045
# 2               36,567                    0               15,427
#
#   Attendances (Total)  Attendances in 4 hours or less (Type 1)  \
# 0               25,706                                   9,432
# 1               32,485                                   6,097
# 2               51,994                                  21,443
#
#   Attendances in 4 hours or less (Type 2) Attendances under 4 hours (Type 3)  \
# 0                                     249                              8,855
# 1                                       0                              6,719
# 2                                       0                             15,427
#
#   Attendances under 4 hours (Total)  ... Emergency Admissions via Type 2 A&E  \
# 0                            18,536  ...                                   0
# 1                            12,816  ...                                   0
# 2                            36,870  ...                                   0
#
#    Emergency Admissions via Type 3 and 4 A&E  \
# 0                                          8
# 1                                          0
# 2                                          0
#
#   Total Emergency Admissions via A&E  \
# 0                              5,318
# 1                              6,195
# 2                              9,699
#
#   Other Emergency admissions (i.e not via A&E) Total Emergency Admissions  \
# 0                                        3,136                      8,454
# 1                                        2,006                      8,201
# 2                                        4,654                     14,353
#
#   Number of patients spending >4 hours from decision to admit to admission  \
# 0                                              2,070
# 1                                                373
# 2                                              4,983
#
#   Number of patients spending >12 hours from decision to admit to admission  \
# 0                                                158
# 1                                                  0
# 2                                                271
#
#    date_str       date  tier3
# 0  April-22 2022-04-01  False
# 1  April-22 2022-04-01  False
# 2  April-22 2022-04-01  False
#
# [3 rows x 29 columns]

# %%
data_icb_totals = data_icb_all[[
    'Code', 'System', 'Attendances (Total) ',
    'Attendances under 4 hours (Total)', 'Attendances over 4 hours (Total)',
    'Percentage in 4 hours or less (Total)',
    'Total Emergency Admissions via A&E',
    'Other Emergency admissions (i.e not via A&E)',
    'Total Emergency Admissions',
    'Number of patients spending >4 hours from decision to admit to admission',
    'Number of patients spending >12 hours from decision to admit to admission',
    'date_str', 'date', 'tier3'
]]

data_icb_totals.columns = [x.strip() for x in data_icb_totals.columns.tolist()]

data_icb_totals
# Out:
#    Code                                             System  \
# 0   QOX  NHS Bath And North East Somerset, Swindon And ...
# 1   QHG  NHS Bedfordshire, Luton And Milton Keynes Inte...
# 2   QHL  NHS Birmingham And Solihull Integrated Care Board
# 3   QUY  NHS Bristol, North Somerset And South Gloucest...
# 4   QU9  NHS Buckinghamshire, Oxfordshire And Berkshire...
# ..  ...                                                ...
# 37  QJG  NHS Suffolk And North East Essex Integrated Ca...
# 38  QXU        NHS Surrey Heartlands Integrated Care Board
# 39  QNX                   NHS Sussex Integrated Care Board
# 40  QUA            NHS Black Country Integrated Care Board
# 41  QWO           NHS West Yorkshire Integrated Care Board
#
#    Attendances (Total) Attendances under 4 hours (Total)  \
# 0               25,706                            18,536
# 1               32,485                            12,816
# 2               51,994                            36,870
# 3               27,466                            18,061
# 4               43,735                            31,326
# ..                 ...                               ...
# 37              33,261                            23,784
# 38              32,981                            23,725
# 39              62,845                            48,543
# 40              73,634                            54,568
# 41              87,051                            62,142
#
#    Attendances over 4 hours (Total) Percentage in 4 hours or less (Total)  \
# 0                             7,170                                72.10%
# 1                             2,099                                85.90%
# 2                            15,124                                70.90%
# 3                             9,405                                65.80%
# 4                            12,409                                71.60%
# ..                              ...                                   ...
# 37                            9,477                                71.50%
# 38                            9,256                                71.90%
# 39                           14,302                                77.20%
# 40                           19,066                                74.10%
# 41                           24,909                                71.40%
#
#    Total Emergency Admissions via A&E  \
# 0                               5,318
# 1                               6,195
# 2                               9,699
# 3                               6,041
# 4                              10,163
# ..                                ...
# 37                              6,724
# 38                              7,784
# 39                             11,483
# 40                             14,895
# 41                             14,639
#
#    Other Emergency admissions (i.e not via A&E) Total Emergency Admissions  \
# 0                                         3,136                      8,454
# 1                                         2,006                      8,201
# 2                                         4,654                     14,353
# 3                                         2,509                      8,550
# 4                                         5,483                     15,646
# ..                                          ...                        ...
# 37                                        1,401                      8,125
# 38                                        2,234                     10,018
# 39                                        2,428                     13,911
# 40                                        3,826                     18,721
# 41                                        4,907                     19,546
#
#    Number of patients spending >4 hours from decision to admit to admission  \
# 0                                               2,070
# 1                                                 373
# 2                                               4,983
# 3                                               2,720
# 4                                               1,804
# ..                                                ...
# 37                                              2,532
# 38                                              1,959
# 39                                              2,536
# 40                                              5,185
# 41                                              6,334
#
#    Number of patients spending >12 hours from decision to admit to admission  \
# 0                                                 158
# 1                                                   0
# 2                                                 271
# 3                                               1,169
# 4                                                   1
# ..                                                ...
# 37                                              1,180
# 38                                                271
# 39                                                784
# 40                                                352
# 41                                                567
#
#         date_str       date tier3
# 0       April-22 2022-04-01    No
# 1       April-22 2022-04-01    No
# 2       April-22 2022-04-01    No
# 3       April-22 2022-04-01    No
# 4       April-22 2022-04-01    No
# ..           ...        ...   ...
# 37  September-23 2023-09-01    No
# 38  September-23 2023-09-01    No
# 39  September-23 2023-09-01    No
# 40  September-23 2023-09-01    No
# 41  September-23 2023-09-01    No
#
# [924 rows x 14 columns]

# %%
numeric_cols = [
    'Attendances (Total)',
    'Attendances under 4 hours (Total)', 'Attendances over 4 hours (Total)',
    'Total Emergency Admissions via A&E',
    'Other Emergency admissions (i.e not via A&E)',
    'Total Emergency Admissions',
    'Number of patients spending >4 hours from decision to admit to admission',
    'Number of patients spending >12 hours from decision to admit to admission'
]
percent_col =  'Percentage in 4 hours or less (Total)'
data_icb_totals['Percentage in 4 hours or less (Total)'] = pd.to_numeric(data_icb_totals['Percentage in 4 hours or less (Total)'].apply(lambda x: x[:-1]))


def remove_alphachars(string):
    return ''.join(c for c in str(string) if c in digits)
    
## This breaks the % figure!
for i in numeric_cols:
    data_icb_totals[i] = data_icb_totals[i].apply(remove_alphachars)
    data_icb_totals[i] = pd.to_numeric(data_icb_totals[i])
# Out:
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\293641350.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\293641350.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\293641350.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_icb_totals.to_csv('../data/cleaned_data.csv', index=False)

# %%
tier3_agg = data_icb_totals.groupby(['date', 'tier3'], as_index=False).agg({
    'Attendances (Total)': sum,
    'Attendances under 4 hours (Total)': sum, 
    'Attendances over 4 hours (Total)': sum,
    'System': pd.Series.nunique})
# Out:
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\3790343292.py:1: FutureWarning:
#
# The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#
# C:\Users\spoic\AppData\Local\Temp\ipykernel_10508\3790343292.py:1: FutureWarning:
#
# The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.

# %%
METRIC = 'Attendances under 4 hours (Total)'
tier3_agg['average'] = tier3_agg[METRIC] / tier3_agg['System']
METRIC2 = 'Attendances under 4 hours (Total)'
tier3_agg['percentage'] = tier3_agg[METRIC2] / tier3_agg['Attendances (Total)'] * 100

fig = px.line(tier3_agg, x="date", y="percentage", color="tier3",
              title=f"% {METRIC2}, Tier 3 vs Rest")
fig.show()

# %%
data_icb_totals
# Out:
#    Code                                             System  \
# 0   QOX  NHS Bath And North East Somerset, Swindon And ...
# 1   QHG  NHS Bedfordshire, Luton And Milton Keynes Inte...
# 2   QHL  NHS Birmingham And Solihull Integrated Care Board
# 3   QUY  NHS Bristol, North Somerset And South Gloucest...
# 4   QU9  NHS Buckinghamshire, Oxfordshire And Berkshire...
# ..  ...                                                ...
# 37  QJG  NHS Suffolk And North East Essex Integrated Ca...
# 38  QXU        NHS Surrey Heartlands Integrated Care Board
# 39  QNX                   NHS Sussex Integrated Care Board
# 40  QUA            NHS Black Country Integrated Care Board
# 41  QWO           NHS West Yorkshire Integrated Care Board
#
#     Attendances (Total)  Attendances under 4 hours (Total)  \
# 0                 25706                              18536
# 1                 32485                              12816
# 2                 51994                              36870
# 3                 27466                              18061
# 4                 43735                              31326
# ..                  ...                                ...
# 37                33261                              23784
# 38                32981                              23725
# 39                62845                              48543
# 40                73634                              54568
# 41                87051                              62142
#
#     Attendances over 4 hours (Total)  Percentage in 4 hours or less (Total)  \
# 0                               7170                                   7210
# 1                               2099                                   8590
# 2                              15124                                   7090
# 3                               9405                                   6580
# 4                              12409                                   7160
# ..                               ...                                    ...
# 37                              9477                                   7150
# 38                              9256                                   7190
# 39                             14302                                   7720
# 40                             19066                                   7410
# 41                             24909                                   7140
#
#     Total Emergency Admissions via A&E  \
# 0                                 5318
# 1                                 6195
# 2                                 9699
# 3                                 6041
# 4                                10163
# ..                                 ...
# 37                                6724
# 38                                7784
# 39                               11483
# 40                               14895
# 41                               14639
#
#     Other Emergency admissions (i.e not via A&E)  Total Emergency Admissions  \
# 0                                           3136                        8454
# 1                                           2006                        8201
# 2                                           4654                       14353
# 3                                           2509                        8550
# 4                                           5483                       15646
# ..                                           ...                         ...
# 37                                          1401                        8125
# 38                                          2234                       10018
# 39                                          2428                       13911
# 40                                          3826                       18721
# 41                                          4907                       19546
#
#     Number of patients spending >4 hours from decision to admit to admission  \
# 0                                                2070
# 1                                                 373
# 2                                                4983
# 3                                                2720
# 4                                                1804
# ..                                                ...
# 37                                               2532
# 38                                               1959
# 39                                               2536
# 40                                               5185
# 41                                               6334
#
#     Number of patients spending >12 hours from decision to admit to admission  \
# 0                                                 158
# 1                                                   0
# 2                                                 271
# 3                                                1169
# 4                                                   1
# ..                                                ...
# 37                                               1180
# 38                                                271
# 39                                                784
# 40                                                352
# 41                                                567
#
#         date_str       date tier3  percentage
# 0       April-22 2022-04-01    No   27.892321
# 1       April-22 2022-04-01    No    6.461444
# 2       April-22 2022-04-01    No   29.087972
# 3       April-22 2022-04-01    No   34.242336
# 4       April-22 2022-04-01    No   28.373157
# ..           ...        ...   ...         ...
# 37  September-23 2023-09-01    No   28.492829
# 38  September-23 2023-09-01    No   28.064643
# 39  September-23 2023-09-01    No   22.757578
# 40  September-23 2023-09-01    No   25.892930
# 41  September-23 2023-09-01    No   28.614261
#
# [924 rows x 15 columns]

# %%
data_icb_totals['']

# %% [markdown]
# ## Open Geography Portal API

# %%
endpoint_IMD19 = "https://services3.arcgis.com/ivmBBrHfQfDnDf8Q/arcgis/rest/services/Indices_of_Multiple_Deprivation_(IMD)_2019/FeatureServer/0/query"

params = {
    "where": "LADcd = 'E09000022'",
    "outSR": 4326,
    "f": "geoJSON",
    "resultOffset": 0,
    "outFields": "*"
}

_, gdf = request_to_gdf(endpoint_IMD19, params)
gdf.head()
# Out:
#                                             geometry   FID   lsoa11cd  \
# 0  POLYGON ((-0.11479 51.50058, -0.11440 51.49987...  2553  E01003013
# 1  POLYGON ((-0.10949 51.49838, -0.11012 51.49716...  2554  E01003014
# 2  POLYGON ((-0.11267 51.49550, -0.11242 51.49525...  2555  E01003015
# 3  POLYGON ((-0.10890 51.50844, -0.10881 51.50792...  2556  E01003016
# 4  POLYGON ((-0.10697 51.50622, -0.10647 51.50506...  2557  E01003017
#
#        lsoa11nm     lsoa11nmw     st_areasha   st_lengths  IMD_Rank  \
# 0  Lambeth 036A  Lambeth 036A  343731.285986  4460.477307     21865
# 1  Lambeth 036B  Lambeth 036B  187536.067480  2836.622325     10007
# 2  Lambeth 002A  Lambeth 002A   94114.483716  1502.576162      9771
# 3  Lambeth 036C  Lambeth 036C  161136.163315  2034.085795     20774
# 4  Lambeth 036D  Lambeth 036D  131261.855190  1684.236054     11736
#
#    IMD_Decile      LSOA01NM  ... OutScore OutRank  OutDec  TotPop  DepChi  \
# 0           7  Lambeth 036A  ...    2.183     185       1    1671     125
# 1           4  Lambeth 036B  ...    2.528      25       1    1656     215
# 2           3  Lambeth 002A  ...    2.349      68       1    1700     277
# 3           7  Lambeth 036C  ...    3.310       1       1    2628     127
# 4           4  Lambeth 036D  ...    2.561      17       1    1928     175
#
#    Pop16_59  Pop60_  WorkPop    Shape__Area  Shape__Length
# 0      1395     151  1467.25  885947.224899    7163.535731
# 1      1155     286  1148.00  483318.401237    4554.029028
# 2      1164     259  1169.75  242524.202126    2412.055010
# 3      2336     165  2264.25  415449.422173    3265.328019
# 4      1434     319  1463.00  338398.576820    2704.786761
#
# [5 rows x 67 columns]

# %%
gdf.explore(column="IMD_Decile", tooltip=['lsoa11nm', 'IMD_Decile', 'IMD_Rank'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27fce248d4721b62922b007682204768 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27fce248d4721b62922b007682204768&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27fce248d4721b62922b007682204768 = L.map(
#                 &quot;map_27fce248d4721b62922b007682204768&quot;,
#                 {
#                     center: [51.45974694962965, -0.1147362951114879],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_27fce248d4721b62922b007682204768);
#
#
#
#
#
#             var tile_layer_b25a49ba94246c4d4fac4456db12259e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b25a49ba94246c4d4fac4456db12259e.addTo(map_27fce248d4721b62922b007682204768);
#
#
#             map_27fce248d4721b62922b007682204768.fitBounds(
#                 [[51.4110520309706, -0.15120602133609], [51.5084418682887, -0.0782665688868858]],
#                 {}
#             );
#
#
#         function geo_json_d9f5e5058874c0e1ccab1a73fc31b559_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;3&quot;: case &quot;51&quot;: case &quot;125&quot;: case &quot;138&quot;: case &quot;143&quot;: case &quot;156&quot;:
#                     return {&quot;color&quot;: &quot;#4ac16d&quot;, &quot;fillColor&quot;: &quot;#4ac16d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;7&quot;: case &quot;12&quot;: case &quot;18&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;45&quot;: case &quot;49&quot;: case &quot;61&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;83&quot;: case &quot;85&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;108&quot;: case &quot;113&quot;: case &quot;115&quot;: case &quot;119&quot;: case &quot;122&quot;: case &quot;127&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;136&quot;: case &quot;151&quot;: case &quot;155&quot;: case &quot;157&quot;: case &quot;163&quot;: case &quot;164&quot;: case &quot;166&quot;:
#                     return {&quot;color&quot;: &quot;#365c8d&quot;, &quot;fillColor&quot;: &quot;#365c8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;11&quot;: case &quot;19&quot;: case &quot;37&quot;: case &quot;43&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;60&quot;: case &quot;66&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;73&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;81&quot;: case &quot;84&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;98&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;118&quot;: case &quot;121&quot;: case &quot;123&quot;: case &quot;129&quot;: case &quot;137&quot;: case &quot;140&quot;: case &quot;146&quot;: case &quot;148&quot;: case &quot;150&quot;: case &quot;158&quot;: case &quot;165&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;171&quot;: case &quot;177&quot;:
#                     return {&quot;color&quot;: &quot;#46327e&quot;, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;21&quot;: case &quot;27&quot;: case &quot;54&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;67&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;82&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;109&quot;: case &quot;117&quot;: case &quot;120&quot;: case &quot;128&quot;: case &quot;133&quot;: case &quot;134&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;147&quot;: case &quot;152&quot;: case &quot;172&quot;: cas
